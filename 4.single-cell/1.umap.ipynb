# %%
import umap
import pathlib
import warnings
import numpy as np
import pandas as pd
import plotnine as gg

from utils.data_utils import load_data
from utils.umap_utils import apply_umap, plot_umap_cell_line, plot_umap_well

# %%
np.random.seed(123)

# %% [markdown]
# ## Load Data

# %%
data_dict = load_data(
    return_meta=True,
    shuffle_row_order=True,
    holdout=True,
    othertreatment=True
)

print(data_dict["train"]["x"].shape)
print(data_dict["test"]["x"].shape)
print(data_dict["holdout"]["x"].shape)
print(data_dict["othertreatment"]["x"].shape)

data_dict["test"]["x"].head(3)
# Out:
# (12608, 1954)
# (2225, 1954)
# (9559, 1954)
# (44717, 1954)
#    Cells_AreaShape_Center_X  Cells_AreaShape_Center_Y  \
# 0                 -0.113122                 -1.158585
# 1                  1.465688                 -1.122811
# 2                  1.473989                 -0.782957
#
#    Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                     0.261311                      0.827214
# 1                    -0.626813                     -0.132303
# 2                     0.899905                      0.944613
#
#    Cells_AreaShape_Extent  Cells_AreaShape_FormFactor  \
# 0               -0.188444                    0.288551
# 1                0.749095                    0.613124
# 2               -1.360331                   -0.573540
#
#    Cells_AreaShape_MeanRadius  Cells_AreaShape_MinFeretDiameter  \
# 0                    0.833495                          0.692469
# 1                   -0.504588                         -0.577071
# 2                   -0.191199                          0.180120
#
#    Cells_AreaShape_MinorAxisLength  Cells_AreaShape_Orientation  ...  \
# 0                         0.485445                    -0.231003  ...
# 1                        -0.644713                    -0.076937  ...
# 2                        -0.068252                    -0.565778  ...
#
#    Nuclei_Texture_Variance_Mito_5_02  Nuclei_Texture_Variance_Mito_5_03  \
# 0                          -0.134343                          -0.173345
# 1                          -0.460578                          -0.446758
# 2                          -0.676248                          -0.678539
#
#    Nuclei_Texture_Variance_RNA_10_00  Nuclei_Texture_Variance_RNA_10_01  \
# 0                          -0.327180                          -0.319798
# 1                          -0.347112                          -0.357332
# 2                          -0.335342                          -0.347834
#
#    Nuclei_Texture_Variance_RNA_10_02  Nuclei_Texture_Variance_RNA_10_03  \
# 0                          -0.292235                          -0.300754
# 1                          -0.369249                          -0.366352
# 2                          -0.314208                          -0.336320
#
#    Nuclei_Texture_Variance_RNA_5_00  Nuclei_Texture_Variance_RNA_5_01  \
# 0                         -0.294313                         -0.272596
# 1                         -0.341890                         -0.381791
# 2                         -0.319980                         -0.322069
#
#    Nuclei_Texture_Variance_RNA_5_02  Nuclei_Texture_Variance_RNA_5_03
# 0                         -0.251354                         -0.292422
# 1                         -0.394011                         -0.375683
# 2                         -0.325911                         -0.329538
#
# [3 rows x 1954 columns]

# %% [markdown]
# ## Apply and visualize UMAP

# %%
embedding_dict = {}

for data_fit in ["train", "test", "holdout", "othertreatment"]:
    embedding_dict[data_fit] = apply_umap(
        data_dict[data_fit]["x"], data_dict[data_fit]["meta"]
    )

# %%
cell_line_column = "Metadata_clone_number"
well_column = "Metadata_Well"

cell_line_labels = {"Clone A": "Clone A", "Clone E": "Clone E", "WT parental": "WT parental"}
cell_line_colors = {"Clone A": "#1b9e77", "Clone E": "#d95f02", "WT parental": "#7570b3"}

# %%
for data_fit, embedding_df in embedding_dict.items():
    fig_file = pathlib.Path("figures", "umap", f"single_cell_umap_{data_fit}.png")
    
    cell_gg = plot_umap_cell_line(
        embedding_df,
        fig_file,
        cell_line_column,
        cell_line_labels,
        cell_line_colors
    )
    
    print(cell_gg)
    
    fig_file = pathlib.Path("figures", "umap", f"single_cell_umap_well_{data_fit}.png")
    well_gg = plot_umap_well(embedding_df, fig_file, well_column)
    print(well_gg)
# Out:
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 5 x 4 in image.
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: figures/umap/single_cell_umap_train.png
# <ggplot: (309511530)>
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 5 x 4 in image.
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: figures/umap/single_cell_umap_well_train.png
# <ggplot: (-9223372036544985449)>
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 5 x 4 in image.
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: figures/umap/single_cell_umap_test.png
# <ggplot: (306429132)>
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 5 x 4 in image.
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: figures/umap/single_cell_umap_well_test.png
# <ggplot: (-9223372036544094036)>
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 5 x 4 in image.
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: figures/umap/single_cell_umap_holdout.png
# <ggplot: (-9223372036544985442)>
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 5 x 4 in image.
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: figures/umap/single_cell_umap_well_holdout.png
# <ggplot: (309787119)>
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 5 x 4 in image.
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: figures/umap/single_cell_umap_othertreatment.png
# <ggplot: (-9223372036540197593)>
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 5 x 4 in image.
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: figures/umap/single_cell_umap_well_othertreatment.png
# <ggplot: (-9223372036508818828)>

# %%
treatment_gg = (
    gg.ggplot(embedding_dict["othertreatment"], gg.aes(x="x", y="y")) +
    gg.geom_point(gg.aes(color="Metadata_treatment"), size = 0.2, shape = ".", alpha = 0.2) +
    gg.theme_bw() 
)

fig_file = pathlib.Path("figures", "umap", "single_cell_othertreatment.png")
treatment_gg.save(filename=fig_file, height=4, width=5, dpi=500)

treatment_gg
# Out:
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 5 x 4 in image.
# /Users/gway/miniconda3/envs/resistance-mechanisms/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: figures/umap/single_cell_othertreatment.png
# <ggplot: (320624879)>
